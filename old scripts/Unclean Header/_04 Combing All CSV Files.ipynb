# %%
import pandas as pd
import numpy as np
import xlrd
from pathlib import Path
import glob
import os

# %%
#set to the file extension of "to-be-merged" files
ext = ".csv"
#set to your working directory
dir_path = 'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs'
#set to the name of your output file
#results = 'ACSSF_2012_2016_Full.txt'

files = os.listdir('C:\\Census Data - Uncleaned Headers\\Cleaned CSVs')

#e20161ak0001000
#e = estimates
#2016 = year
#1 = 1 year estimate vs. 5 year
#ak = state
#0001 = sequence number
#000 = iterationID

#files2 = [k for k in files if '11' in k]
#files3 = [k for k in files2 if 'e2016' in k]
#files3 = [k for k in files2 if '0041' in k]


string = 'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\'
files4 = [string + x for x in files]
files4
# Out:
# ['C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\BK',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile1.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile10.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile100.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile101.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile102.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile103.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile104.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile105.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile106.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile107.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile108.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile109.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile11.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile110.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile111.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile112.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile113.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile114.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile115.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile116.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile117.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile118.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile119.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile12.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile120.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile121.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile122.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile13.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile14.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile15.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile16.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile17.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile18.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile19.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile2.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile20.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile21.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile22.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile23.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile24.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile25.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile26.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile27.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile28.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile29.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile3.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile30.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile31.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile32.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile33.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile34.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile35.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile36.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile37.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile38.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile39.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile4.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile40.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile41.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile42.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile43.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile44.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile45.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile46.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile47.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile48.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile49.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile5.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile50.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile51.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile52.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile53.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile54.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile55.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile56.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile57.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile58.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile59.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile6.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile60.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile61.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile62.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile63.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile64.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile65.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile66.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile67.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile68.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile69.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile7.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile70.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile71.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile72.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile73.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile74.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile75.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile76.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile77.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile78.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile79.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile8.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile80.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile81.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile82.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile83.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile84.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile85.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile86.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile87.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile88.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile89.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile9.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile90.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile91.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile92.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile93.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile94.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile95.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile96.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile97.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile98.csv',
#  'C:\\Census Data - Uncleaned Headers\\Cleaned CSVs\\csvfile99.csv']

# %%
logfile = pd.read_csv("C:\\Census Data - Uncleaned Headers\\LogRecReference.csv", engine='python')
logfile = logfile.drop(['source','Unnamed: 0','Name'], 1)

# %%
for f in files4:
  if f.endswith(ext):
    data = open(f)
    
        
    inputcsv = pd.read_csv(data,  engine='python')
    
    inputcsv = inputcsv.drop(['Unnamed: 0','GEOID','Name','FILETYPE','FILEID','CHARITER','SEQUENCE'], 1)
    #inputcsv = inputcsv.drop(['4','1','Unnamed: 0','GEOID','Name','YEAR'], 1)
    #inputcsv = inputcsv.rename(index=str, columns= {'SEQUENCE' : 'SEQ'})

    
    #newcolumn = inputcsv['SEQ'].values
    #seq_num = str(newcolumn[0])[0:2]
    #new_Seq_columnname = "SEQ" + seq_num + "_"   

    #columnnames = inputcsv.columns[~inputcsv.columns.str.contains('STATE|SEQ|LOGRECNO')]
    #inputcsv.rename(columns = dict(zip(columnnames, new_Seq_columnname + columnnames)),inplace=True)
    
    logfile = pd.merge(logfile, inputcsv, on = ['LOGRECNO', 'STATE'], how = "left")    
    
    #newcolumn = logfile['SEQ'].values

    #seq_num = str(newcolumn[0])[0:2]
    #seq_num = seq_num[0: seq_num.find(".")]
    #new_Seq_columnname = "SEQ_"+ seq_num
        

    #logfile.rename(columns = {'SEQ' : new_Seq_columnname}, inplace=True)
    
    data.close()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-34-6f2e08f6ea06> in <module>()
#      18     #inputcsv.rename(columns = dict(zip(columnnames, new_Seq_columnname + columnnames)),inplace=True)
#      19
# ---> 20     logfile = pd.merge(logfile, inputcsv, on = ['LOGRECNO', 'STATE'], how = "left")
#      21
#      22     #newcolumn = logfile['SEQ'].values
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      60                          copy=copy, indicator=indicator,
#      61                          validate=validate)
# ---> 62     return op.get_result()
#      63
#      64
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     580             [(ldata, lindexers), (rdata, rindexers)],
#     581             axes=[llabels.append(rlabels), join_index],
# --> 582             concat_axis=0, copy=self.copy)
#     583
#     584         typ = self.left._constructor
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    5419         else:
#    5420             b = make_block(
# -> 5421                 concatenate_join_units(join_units, concat_axis, copy=copy),
#    5422                 placement=placement)
#    5423         blocks.append(b)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in concatenate_join_units(join_units, concat_axis, copy)
#    5563     to_concat = [ju.get_reindexed_values(empty_dtype=empty_dtype,
#    5564                                          upcasted_na=upcasted_na)
# -> 5565                  for ju in join_units]
#    5566
#    5567     if len(to_concat) == 1:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in <listcomp>(.0)
#    5563     to_concat = [ju.get_reindexed_values(empty_dtype=empty_dtype,
#    5564                                          upcasted_na=upcasted_na)
# -> 5565                  for ju in join_units]
#    5566
#    5567     if len(to_concat) == 1:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in get_reindexed_values(self, empty_dtype, upcasted_na)
#    5873             for ax, indexer in self.indexers.items():
#    5874                 values = algos.take_nd(values, indexer, axis=ax,
# -> 5875                                        fill_value=fill_value)
#    5876
#    5877         return values
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\algorithms.py in take_nd(arr, indexer, axis, out, fill_value, mask_info, allow_fill)
#    1653             out = np.empty(out_shape, dtype=dtype, order='F')
#    1654         else:
# -> 1655             out = np.empty(out_shape, dtype=dtype)
#    1656
#    1657     func = _get_take_nd_function(arr.ndim, arr.dtype, out.dtype, axis=axis,
#
# MemoryError:

# %%
logfile
# Out:
#        STATE  LOGRECNO           GEOID  B05011_001  B05011_002  B05011_003  \
# 0         AK         1       04000US02     55247.0     24109.0     31138.0
# 1         AK         2       04001US02     43659.0     18568.0     25091.0
# 2         AK         3       04043US02     11588.0      5541.0      6047.0
# 3         AK         4       040A0US02     43019.0     17847.0     25172.0
# 4         AK         5       040C0US02     39241.0     16142.0     23099.0
# 5         AK         6       040C1US02     33404.0     13616.0     19788.0
# 6         AK         7       040C2US02      5837.0      2526.0      3311.0
# 7         AK         8       040E0US02      3778.0      1705.0      2073.0
# 8         AK         9       040E1US02      3675.0      1660.0      2015.0
# 9         AK        10       040E2US02       103.0        45.0        58.0
# 10        AK        11       040G0US02     12228.0      6262.0      5966.0
# 11        AK        12       040H0US02     16006.0      7967.0      8039.0
# 12        AK        13    05000US02013      1342.0       926.0       416.0
# 13        AK        14    05000US02016      2105.0      1228.0       877.0
# 14        AK        15    05000US02020     30806.0     12409.0     18397.0
# 15        AK        16    05000US02050       322.0       170.0       152.0
# 16        AK        17    05000US02060        23.0         9.0        14.0
# 17        AK        18    05000US02068       132.0       111.0        21.0
# 18        AK        19    05000US02070       122.0        44.0        78.0
# 19        AK        20    05000US02090      5199.0      2388.0      2811.0
# 20        AK        21    05000US02100       123.0        81.0        42.0
# 21        AK        22    05000US02105       127.0        73.0        54.0
# 13           220.0       209.0        98.0       176.0     ...
# 14          3229.0      4052.0      2372.0      2391.0     ...
# 15            10.0        18.0        26.0        30.0     ...
# 16             3.0         0.0         7.0         3.0     ...
# 17             4.0        12.0         5.0         0.0     ...
# 18             6.0        46.0         4.0        11.0     ...
# 19           646.0       513.0       338.0       283.0     ...
# 20            32.0         2.0         0.0         0.0     ...
# 21            27.0         2.0        13.0         3.0     ...
# 22           246.0       298.0       166.0       167.0     ...
# 23           157.0        61.0        92.0        52.0     ...
# 24           103.0       154.0        94.0        85.0     ...
# 25           318.0       238.0       296.0       181.0     ...
# 26             1.0         0.0         0.0         6.0     ...
# 27             0.0         2.0        11.0         2.0     ...
# 28           317.0       399.0       210.0       239.0     ...
# 29             6.0        12.0        18.0         7.0     ...
# ...            ...         ...         ...         ...     ...
# 579016        25.0         3.0        47.0         0.0     ...
# 579017         0.0         5.0         2.0         4.0     ...
# 579018         5.0         3.0         0.0        10.0     ...
# 579019         0.0         5.0         7.0         0.0     ...
# 579020        21.0         0.0        18.0         0.0     ...
# 579021         9.0        15.0         4.0         7.0     ...
# 579022        29.0         0.0        12.0        12.0     ...
# 579023         0.0        28.0         0.0         0.0     ...
# 579024         0.0         0.0         0.0         0.0     ...
# 579025         0.0         0.0         1.0         0.0     ...
# 579026         0.0         4.0         0.0         2.0     ...
# 579027         0.0         0.0         0.0         0.0     ...
# 579028         0.0         0.0         0.0         0.0     ...
# 579029       328.0       273.0       172.0        81.0     ...
# 579030         0.0        37.0        77.0        31.0     ...
# 579031         4.0         0.0         0.0         0.0     ...
# 579032         0.0        12.0         0.0         0.0     ...
# 579033         4.0        79.0        26.0        22.0     ...
# 579034        19.0        20.0         0.0        12.0     ...
# 579035        62.0       103.0        24.0        15.0     ...
# 579036         0.0         0.0         0.0         0.0     ...
# 579037         0.0         2.0         0.0         3.0     ...
# 579038       111.0        86.0         0.0       129.0     ...
# 579039         3.0         6.0         0.0         0.0     ...
# 579040        37.0        33.0        14.0        56.0     ...
# 579041         0.0         0.0         0.0         0.0     ...
# 579042       241.0       194.0        66.0         1.0     ...
# 579043         0.0         0.0         0.0         0.0     ...
# 579044        24.0        82.0        15.0        10.0     ...
# 579045         5.0         0.0         0.0         0.0     ...
#
#         B23022_040  B23022_041  B23022_042  B23022_043  B23022_044  \
# 0           5123.0      5755.0     10291.0      2417.0       115.0
# 1           2946.0      3519.0      6129.0      1422.0        47.0
# 2           2177.0      2236.0      4162.0       995.0        68.0
# 3           3282.0      3876.0      7262.0      1721.0        68.0
# 4           3015.0      3473.0      6658.0      1543.0        62.0
# 5           1857.0      2262.0      4146.0       982.0        31.0
# 6           1158.0      1211.0      2512.0       561.0        31.0
# 7            267.0       403.0       604.0       178.0         6.0
# 8            232.0       357.0       528.0       137.0         6.0
# 9             35.0        46.0        76.0        41.0         0.0
# 10          1841.0      1879.0      3029.0       696.0        47.0
# 11          2108.0      2282.0      3633.0       874.0        53.0
# 12            32.0        27.0        41.0        11.0         0.0
# 11           239.0       491.0       607.0      1369.0     16558.0
# 12             4.0         4.0         6.0        16.0        91.0
# 13             0.0         1.0         7.0        14.0       346.0
# 14           281.0       927.0       431.0      1315.0     20702.0
# 15            10.0        52.0        41.0       124.0      1458.0
# 16             0.0         3.0         3.0         5.0        48.0
# 17            14.0         2.0         1.0        19.0       124.0
# 18             0.0        11.0         5.0        35.0       339.0
# 19           132.0       216.0       186.0       387.0      7019.0
# 20             0.0         8.0        26.0         2.0       174.0
# 21             1.0         0.0        10.0        18.0       124.0
# 22            27.0        76.0        94.0       110.0      1641.0
# 23            42.0       179.0       187.0       361.0      4880.0
# 24            11.0        25.0        30.0        47.0       964.0
# 25            37.0        11.0        57.0        85.0       780.0
# 26             7.0         9.0        10.0        87.0       699.0
# 27             2.0         3.0         4.0        24.0        78.0
# 28            98.0       232.0       247.0       601.0     10020.0
# 29             4.0        27.0        18.0        84.0       718.0
# ...            ...         ...         ...         ...         ...
# 579016        37.0         8.0         6.0       109.0      1002.0
# 579017         0.0         4.0         5.0        20.0       209.0
# 579018         0.0         3.0         1.0         0.0        83.0
# 579019         8.0        32.0        28.0         8.0       332.0
# 579020         0.0         0.0        99.0        32.0       395.0
# 579021         6.0         0.0        15.0        30.0       174.0
# 579022        15.0        62.0        42.0        60.0       846.0
# 579023         0.0        58.0        37.0         1.0       510.0
# 579024         0.0         0.0         3.0        16.0       306.0
# 579025         9.0        47.0         0.0        23.0       284.0
# 579026         0.0         0.0         3.0        12.0        60.0
# 579027         0.0         0.0         3.0         5.0       290.0
# 579028        13.0         8.0        41.0         3.0       218.0
# 579029       116.0       158.0       178.0       221.0      5352.0
# 579030         0.0         6.0        13.0        50.0       375.0
# 579031         0.0        26.0        20.0        23.0       480.0
# 579032         1.0       101.0         0.0        48.0       641.0
# 579033        68.0        71.0        58.0       104.0       612.0
# 579034         0.0        29.0        32.0       120.0      1119.0
# 579035        17.0        76.0       197.0       151.0      2209.0
# 579036         0.0         0.0         0.0         1.0        18.0
# 579037         0.0        31.0        17.0        30.0       488.0
# 579038        13.0        98.0        23.0       115.0      1717.0
# 579039         0.0         6.0         4.0        17.0        90.0
# 579040        22.0        15.0        54.0        41.0      1066.0
# 579041         0.0         3.0         0.0         8.0        56.0
# 579042        23.0         8.0        10.0         0.0       879.0
# 579043         0.0         0.0         0.0        56.0       152.0
# 579044        18.0        33.0         1.0        37.0       545.0
# 579045         0.0         4.0         0.0         3.0       203.0
#
# [579046 rows x 3166 columns]

# %%
#logfile.to_csv("\\\\Aopscifs004.amsa.com\\fs$\\DATA\\GROUP\\Insights and Outcomes\\IOG Projects\\National School District View\\Data\\Census Data\\5 Year Census Data\\2011-2016\\CB2011_2016_Full.csv", sep=',', encoding='utf-8') 
logfile.to_csv("\\\\Aopscifs004.amsa.com\\fs$\\DATA\\GROUP\\Insights and Outcomes\\IOG Projects\\National School District View\\Data\\Census Data\\5 Year Census Data\\2011-2016\\CB2011_2016_FullEVERYTHING.csv", sep=',', encoding='utf-8')
