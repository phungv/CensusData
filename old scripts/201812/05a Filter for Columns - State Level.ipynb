# %%
import pandas as pd
import numpy as np
import xlrd
from pathlib import Path
import glob
import os

# %%
fullfile = pd.read_csv("\\\\Aopscifs004.amsa.com\\fs$\\DATA\\GROUP\\Insights and Outcomes\\IOG Projects\\National School District View\\Data\\201812 Cleaned Data\\FullFile1.csv", engine='python')

# %%
cols =[x for x in fullfile.columns[fullfile.columns.str.contains('STATE|LOGRECNO|GEOID|ATTAINMENT|ENROLLMENT|INCOME|ALLOCATION OF LANGUAGE SPOKEN AT HOME FOR THE POPULATION 5 YEARS|POPULATION UNDER 18 YEARS BY AGE|POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE for Population')]]


fullfile2 = fullfile[cols]

fullfile2.columns = fullfile2.columns.str.strip().str.replace("%", '').str.replace('"', '')

cols2 =[x for x in fullfile2.columns[fullfile2.columns.str.contains('STATE|LOGRECNO|GEOID|SCHOOL ENROLLMENT BY DETAILED  LEVEL OF SCHOOL FOR THE POPULATION 3 YEARS AND OVER for Population 3 Years And Over Enrolled in school|    SCHOOL ENROLLMENT BY DETAILED  LEVEL OF SCHOOL FOR THE POPULATION 3 YEARS AND OVER for Population 3 Years And Over Total|SCHOOL ENROLLMENT BY DETAILED LEVEL OF SCHOOL FOR THE POPULATION 3 YEARS AND OVER BLACK OR AFRICAN AMERICAN ALONE for Black Or African American Alone Population 3 Years And Over Enrolled in school|SCHOOL ENROLLMENT BY DETAILED LEVEL OF SCHOOL FOR THE POPULATION 3 YEARS AND OVER HISPANIC OR LATINO for Hispanic Or Latino Population 3 Years And Over Enrolled in school|SEQ34_POPULATION UNDER 18 YEARS BY AGE for Population Under 18 Years In households|    SEQ34_POPULATION UNDER 18 YEARS BY AGE for Population Under 18 Years In households 12 to 14 years|SEQ34_POPULATION UNDER 18 YEARS BY AGE for Population Under 18 Years In households 15 to 17 years|SEQ34_POPULATION UNDER 18 YEARS BY AGE for Population Under 18 Years In households 3 and 4 years|SEQ34_POPULATION UNDER 18 YEARS BY AGE for Population Under 18 Years In households 5 years|   SEQ34_POPULATION UNDER 18 YEARS BY AGE for Population Under 18 Years In households 6 to 8 years|SEQ34_POPULATION UNDER 18 YEARS BY AGE for Population Under 18 Years In households 9 to 11 years|SEQ34_POPULATION UNDER 18 YEARS BY AGE for Population Under 18 Years In households Under 3 years|SEQ41_SCHOOL ENROLLMENT BY LEVEL OF SCHOOL FOR THE POPULATION 3 YEARS AND OVER for Population 3 Years And Over Enrolled in school|SEQ41_SCHOOL ENROLLMENT BY LEVEL OF SCHOOL FOR THE POPULATION 3 YEARS AND OVER for Population 3 Years And Over Enrolled in school Enrolled in college undergraduate years|SEQ41_SCHOOL ENROLLMENT BY LEVEL OF SCHOOL FOR THE POPULATION 3 YEARS AND OVER for Population 3 Years And Over Enrolled in school Enrolled in grade 1 to grade 4|SEQ41_SCHOOL ENROLLMENT BY LEVEL OF SCHOOL FOR THE POPULAT
ATUS FOR THE POPULATION 25 TO 64 YEARS for Population 25 To 64 Years High school graduate includes equivalency In labor force Civilian Unemployed|SEQ78_EDUCATIONAL ATTAINMENT BY EMPLOYMENT STATUS FOR THE POPULATION 25 TO 64 YEARS for Population 25 To 64 Years Less than high school graduate In labor force Civilian Employed|SEQ78_EDUCATIONAL ATTAINMENT BY EMPLOYMENT STATUS FOR THE POPULATION 25 TO 64 YEARS for Population 25 To 64 Years Less than high school graduate In labor force Civilian Unemployed|SEX BY AGE FOR THE FOREIGN-BORN POPULATION for Foreign-Born Population Female 10 to 14 years|SEX BY AGE FOR THE FOREIGN-BORN POPULATION for Foreign-Born Population Female 15 to 19 years|SEX BY AGE FOR THE FOREIGN-BORN POPULATION for Foreign-Born Population Female 20 to 24 years|SEX BY AGE FOR THE FOREIGN-BORN POPULATION for Foreign-Born Population Female 25 to 29 years|SEX BY AGE FOR THE FOREIGN-BORN POPULATION for Foreign-Born Population Female 5 to 9 years|SEX BY AGE FOR THE FOREIGN-BORN POPULATION for Foreign-Born Population Male 10 to 14 years|SEX BY AGE FOR THE FOREIGN-BORN POPULATION for Foreign-Born Population Male 15 to 19 years|SEX BY AGE FOR THE FOREIGN-BORN POPULATION for Foreign-Born Population Male 20 to 24 years|SEX BY AGE FOR THE FOREIGN-BORN POPULATION for Foreign-Born Population Male 25 to 29 year|SEX BY AGE FOR THE FOREIGN-BORN POPULATION for Foreign-Born Population Male 5 to 9 years')]]
FilteredFile = fullfile2[cols2]

#keep education
#keep Enrollment
#keep proverty
#keep income
#keep ALLOCATION OF LANGUAGE SPOKEN AT HOME FOR THE POPULATION 5 YEARS
#POPULATION UNDER 18 YEARS BY AGE

# %%
FilteredFile
#168 
#FilteredFile.to_csv("\\\\Aopscifs004.amsa.com\\fs$\\DATA\\GROUP\\Insights and Outcomes\\IOG Projects\\CPS Brockton EOC Support\\Data\\FilteredFile.csv", sep=',', encoding='utf-8')
# Out:
#       STATE  LOGRECNO                   GEOID  \
# 0        AK         1               04000US02
# 1        AL         1               04000US01
# 2        AR         1               04000US05
# 3        AZ         1               04000US04
# 4        CA         1               04000US06
# 5        CO         1               04000US08
# 6        CT         1               04000US09
# 7        DC         1               04000US11
# 8        DE         1               04000US10
# 9        FL         1               04000US12
# 10       GA         1               04000US13
# 11       HI         1               04000US15
# 12       IA         1               04000US19
# 13       ID         1               04000US16
# 14       IL         1               04000US17
# 15       IN         1               04000US18
# 16       KS         1               04000US20
# 17       KY         1               04000US21
# 18       LA         1               04000US22
# ...

# %%
#College Enrollment

FilteredFileOrg = FilteredFile
#FilteredFileOrg = pd.read_csv("\\\\Aopscifs004.amsa.com\\fs$\\DATA\\GROUP\\Insights and Outcomes\\IOG Projects\\CPS Brockton EOC Support\\Data\\FilteredFile.csv", sep=',', encoding='utf-8')

#fullfile = pd.read_csv("\\\\Aopscifs004.amsa.com\\fs$\\DATA\\GROUP\\Insights and Outcomes\\IOG Projects\\CPS Brockton EOC Support\\Data\\FullFile.csv", engine='python')

cols =[x for x in fullfile.columns[fullfile.columns.str.contains('STATE|LOGRECNO|GEOID|ATTAINMENT|ENROLLMENT|INCOME|ALLOCATION OF LANGUAGE SPOKEN AT HOME FOR THE POPULATION 5 YEARS|POPULATION UNDER 18 YEARS BY AGE|POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE for Population')]]

fullfile2 = fullfile[cols]

fullfile2.columns = fullfile2.columns.str.strip().str.replace("%", '').str.replace('"', '')

cols2 =[x for x in fullfile2.columns[fullfile2.columns.str.contains('GEOID|college or graduate school|18 and 19 years')]]
FilteredFileAdd = fullfile2[cols2]



#--File41

#SEQ41_SEX BY COLLEGE OR GRADUATE SCHOOL ENROLLMENT BY TYPE OF SCHOOL BY AGE FOR THE POPULATION 15 YEARS AND OVER for Population 15 Years And Over% Male% Enrolled in public college or graduate school% 18 to 24 years
#SEQ41_SEX BY COLLEGE OR GRADUATE SCHOOL ENROLLMENT BY TYPE OF SCHOOL BY AGE FOR THE POPULATION 15 YEARS AND OVER for Population 15 Years And Over% Male% Enrolled in private college or graduate school% 18 to 24 years
#SEQ41_SEX BY COLLEGE OR GRADUATE SCHOOL ENROLLMENT BY TYPE OF SCHOOL BY AGE FOR THE POPULATION 15 YEARS AND OVER for Population 15 Years And Over% Female% Enrolled in public college or graduate school% 18 to 24 years
#SEQ41_SEX BY COLLEGE OR GRADUATE SCHOOL ENROLLMENT BY TYPE OF SCHOOL BY AGE FOR THE POPULATION 15 YEARS AND OVER for Population 15 Years And Over% Female% Enrolled in private college or graduate school% 18 to 24 years
#SEX BY SCHOOL ENROLLMENT BY TYPE OF SCHOOL BY AGE FOR THE POPULATION 3 YEARS AND OVER for Population 3 Years And Over% Male% Enrolled in public school% 18 and 19 years
#SEX BY SCHOOL ENROLLMENT BY TYPE OF SCHOOL BY AGE FOR THE POPULATION 3 YEARS AND OVER for Population 3 Years And Over% Male% Enrolled in private school% 18 and 19 years

# %%
FilteredFileAdd.head()
# Out:
#        GEOID  \
# 0  04000US02
# 1  04000US01
# 2  04000US05
# 3  04000US04
# 4  04000US06
#
#    SEQ41_SEX BY SCHOOL ENROLLMENT BY TYPE OF SCHOOL BY AGE FOR THE POPULATION 3 YEARS AND OVER for Population 3 Years And Over Male Enrolled in public school 18 and 19 years  \
# 0                                             5702.0
# 1                                            42552.0
# 2                                            25050.0
# 3                                            59807.0
# 4                                           358382.0
#
#    SEQ41_SEX BY SCHOOL ENROLLMENT BY TYPE OF SCHOOL BY AGE FOR THE POPULATION 3 YEARS AND OVER for Population 3 Years And Over Male Enrolled in private school 18 and 19 years  \
# 0                                              606.0
# 1                                             5492.0
# 2                                             3457.0
# 3                                             4993.0
# ...

# %%
FilteredFileOrg.head()
# 168
# Out:
#   STATE  LOGRECNO      GEOID  \
# 0    AK         1  04000US02
# 1    AL         1  04000US01
# 2    AR         1  04000US05
# 3    AZ         1  04000US04
# 4    CA         1  04000US06
#
#    SEQ34_POPULATION UNDER 18 YEARS BY AGE for Population Under 18 Years In households  \
# 0                                           186964.0
# 1                                          1102694.0
# 2                                           703910.0
# 3                                          1616827.0
# 4                                          9116755.0
#
#    SEQ34_POPULATION UNDER 18 YEARS BY AGE for Population Under 18 Years In households Under 3 years  \
# 0                                            32668.0
# 1                                           170473.0
# 2                                           112378.0
# 3                                           251985.0
# 4                                          1458258.0
#
# ...

# %%
FilteredFileOrg2 = pd.merge(FilteredFileOrg, FilteredFileAdd, on = ['GEOID'], how = "left")   
#FilteredFile_CHECK = FilteredFile_CHECK.drop(['Unnamed: 0'], 1)

# %%
FilteredFileOrg2.head()
#204
# Out:
#   STATE  LOGRECNO      GEOID  \
# 0    AK         1  04000US02
# 1    AL         1  04000US01
# 2    AR         1  04000US05
# 3    AZ         1  04000US04
# 4    CA         1  04000US06
#
#    SEQ34_POPULATION UNDER 18 YEARS BY AGE for Population Under 18 Years In households  \
# 0                                           186964.0
# 1                                          1102694.0
# 2                                           703910.0
# 3                                          1616827.0
# 4                                          9116755.0
#
#    SEQ34_POPULATION UNDER 18 YEARS BY AGE for Population Under 18 Years In households Under 3 years  \
# 0                                            32668.0
# 1                                           170473.0
# 2                                           112378.0
# 3                                           251985.0
# 4                                          1458258.0
#
# ...

# %%
#Median Household Income Enrollment

FilteredFilep2 = FilteredFile
#FilteredFileOrg = pd.read_csv("\\\\Aopscifs004.amsa.com\\fs$\\DATA\\GROUP\\Insights and Outcomes\\IOG Projects\\CPS Brockton EOC Support\\Data\\FilteredFile.csv", sep=',', encoding='utf-8')

#fullfile = pd.read_csv("\\\\Aopscifs004.amsa.com\\fs$\\DATA\\GROUP\\Insights and Outcomes\\IOG Projects\\CPS Brockton EOC Support\\Data\\FullFile.csv", engine='python')

cols =[x for x in fullfile.columns[fullfile.columns.str.contains('STATE|LOGRECNO|GEOID|ATTAINMENT|ENROLLMENT|INCOME|ALLOCATION OF LANGUAGE SPOKEN AT HOME FOR THE POPULATION 5 YEARS|POPULATION UNDER 18 YEARS BY AGE|POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE for Population')]]

fullfile2 = fullfile[cols]

fullfile2.columns = fullfile2.columns.str.strip().str.replace("%", '').str.replace('"', '')

cols2 =[x for x in fullfile2.columns[fullfile2.columns.str.contains('GEOID|HOUSEHOLD INCOME IN THE PAST 12 MONTHS IN 2016 INFLATION-ADJUSTED DOLLARS for Households')]]

FilteredFileAdd2 = fullfile2[cols2]



#--File59

#HOUSEHOLD INCOME IN THE PAST 12 MONTHS IN 2016 INFLATION-ADJUSTED DOLLARS for Households

# %%
FilteredFileAdd2
#20
# Out:
#                         GEOID  \
# 0                   04000US02
# 1                   04000US01
# 2                   04000US05
# 3                   04000US04
# 4                   04000US06
# 5                   04000US08
# 6                   04000US09
# 7                   04000US11
# 8                   04000US10
# 9                   04000US12
# 10                  04000US13
# 11                  04000US15
# 12                  04000US19
# 13                  04000US16
# 14                  04000US17
# 15                  04000US18
# 16                  04000US20
# 17                  04000US21
# 18                  04000US22
# 19                  04000US25
# 20                  04000US24
# 21                  04000US23
# 22                  04000US26
# 23                  04000US27
# 24                  04000US29
# 25                  04000US28
# 26                  04000US30
# 27                  04000US37
# 28                  04000US38
# 29                  04000US31
# ...

# %%
FilteredFileOrg3 = pd.merge(FilteredFileOrg2, FilteredFileAdd2, on = ['GEOID'], how = "left")   
#FilteredFile_CHECK = FilteredFile_CHECK.drop(['Unnamed: 0'], 1)

# %%
FilteredFileOrg3.head()
#220 columns
# Out:
#   STATE  LOGRECNO      GEOID  \
# 0    AK         1  04000US02
# 1    AL         1  04000US01
# 2    AR         1  04000US05
# 3    AZ         1  04000US04
# 4    CA         1  04000US06
#
#    SEQ34_POPULATION UNDER 18 YEARS BY AGE for Population Under 18 Years In households  \
# 0                                           186964.0
# 1                                          1102694.0
# 2                                           703910.0
# 3                                          1616827.0
# 4                                          9116755.0
#
#    SEQ34_POPULATION UNDER 18 YEARS BY AGE for Population Under 18 Years In households Under 3 years  \
# 0                                            32668.0
# 1                                           170473.0
# 2                                           112378.0
# 3                                           251985.0
# 4                                          1458258.0
#
# ...

# %%
#Median Household Income - Quintiles

FilteredFilep3 = FilteredFile

#FilteredFileOrg = pd.read_csv("\\\\Aopscifs004.amsa.com\\fs$\\DATA\\GROUP\\Insights and Outcomes\\IOG Projects\\CPS Brockton EOC Support\\Data\\FilteredFile.csv", sep=',', encoding='utf-8')

#fullfile = pd.read_csv("\\\\Aopscifs004.amsa.com\\fs$\\DATA\\GROUP\\Insights and Outcomes\\IOG Projects\\CPS Brockton EOC Support\\Data\\FullFile.csv", engine='python')

cols =[x for x in fullfile.columns[fullfile.columns.str.contains('GEOID|HOUSEHOLD INCOME QUINTILE UPPER LIMITS|MEAN HOUSEHOLD INCOME OF QUINTILES')]]

fullfile2 = fullfile[cols]

fullfile2.columns = fullfile2.columns.str.strip().str.replace("%", '').str.replace('"', '')



cols2 =[x for x in fullfile2.columns[fullfile2.columns.str.contains('GEOID|QUINTILE')]]

FilteredFileAdd3 = fullfile2[cols2]


#Median Household Income - Quintiles

# %%
FilteredFileAdd3.head()
# Out:
#        GEOID  \
# 0  04000US02
# 1  04000US01
# 2  04000US05
# 3  04000US04
# 4  04000US06
#
#   SEQ63_HOUSEHOLD INCOME QUINTILE UPPER LIMITS for Households Lowest Quintile  \
# 0                                              33230
# 1                                              17560
# 2                                              17785
# 3                                              21908
# 4                                              25308
#
#   SEQ63_HOUSEHOLD INCOME QUINTILE UPPER LIMITS for Households Second Quintile  \
# 0                                              60461
# 1                                              34662
# 2                                              33231
# 3                                              40761
# 4                                              49774
#
#   SEQ63_HOUSEHOLD INCOME QUINTILE UPPER LIMITS for Households Third Quintile  \
# 0                                              90453
# ...

# %%
FilteredFileOrg4 = pd.merge(FilteredFileOrg3, FilteredFileAdd3, on = ['GEOID'], how = "left")   
#FilteredFile_CHECK = FilteredFile_CHECK.drop(['Unnamed: 0'], 1)

# %%
#Education Attainment for 25 year olds + 
cols =[x for x in fullfile.columns[fullfile.columns.str.contains('STATE|LOGRECNO|GEOID|EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 YEARS')]]


fullfile2 = fullfile[cols]

fullfile2.columns = fullfile2.columns.str.strip().str.replace("%", '').str.replace('"', '')

cols2 = [x for x in fullfile2.columns[fullfile2.columns.str.contains('GEOID|SEQ43')]]
#cols2 = [x for x in fullfile2.columns[fullfile2.columns.str.contains('STATE|LOGRECNO|GEOID|ATTAINMENT')]]



FilteredFileAdd4 = fullfile2[cols2]

#FilteredFileAdd4 = FilteredFileAdd4.drop(['NATIVITY IN THE UNITED STATES for Total Population In The United States Total',''], 1)

#keep education
#keep Enrollment
#keep proverty
#keep income
#keep ALLOCATION OF LANGUAGE SPOKEN AT HOME FOR THE POPULATION 5 YEARS
#POPULATION UNDER 18 YEARS BY AGE

# %%
FilteredFileAdd4.head()
#160 Columns
# Out:
#        GEOID  \
# 0  04000US02
# 1  04000US01
# 2  04000US05
# 3  04000US04
# 4  04000US06
#
#    SEQ43_SEX BY EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 YEARS AND OVER for Population 25 Years And Over Total  \
# 0                                           470699.0
# 1                                          3261408.0
# 2                                          1973591.0
# 3                                          4440635.0
# 4                                         25554412.0
#
#    SEQ43_SEX BY EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 YEARS AND OVER for Population 25 Years And Over Male  \
# 0                                           244249.0
# 1                                          1543623.0
# 2                                           948560.0
# 3                                          2171230.0
# 4                                         12485239.0
#
# ...

# %%
FilteredFile_CHECK = pd.merge(FilteredFileOrg4, FilteredFileAdd4, on = ['GEOID'], how = "left")   
#FilteredFile_CHECK = FilteredFile_CHECK.drop(['Unnamed: 0'], 1)

# %%
FilteredFile_CHECK
#390
# Out:
#       STATE  LOGRECNO                   GEOID  \
# 0        AK         1               04000US02
# 1        AL         1               04000US01
# 2        AR         1               04000US05
# 3        AZ         1               04000US04
# 4        CA         1               04000US06
# 5        CO         1               04000US08
# 6        CT         1               04000US09
# 7        DC         1               04000US11
# 8        DE         1               04000US10
# 9        FL         1               04000US12
# 10       GA         1               04000US13
# 11       HI         1               04000US15
# 12       IA         1               04000US19
# 13       ID         1               04000US16
# 14       IL         1               04000US17
# 15       IN         1               04000US18
# 16       KS         1               04000US20
# 17       KY         1               04000US21
# 18       LA         1               04000US22
# ...

# %%
FilteredFile_CHECK.to_csv("\\\\Aopscifs004.amsa.com\\fs$\\DATA\\GROUP\\Insights and Outcomes\\IOG Projects\\National School District View\\Data\\201812 Cleaned Data\\FilteredFile.csv", sep=',', encoding='utf-8')
