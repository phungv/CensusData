# %%
import pandas as pd
import numpy as np
import xlrd
from pathlib import Path
import glob
import os

# %%
#set to the file extension of "to-be-merged" files
ext = ".csv"
#set to your working directory
dir_path = 'C:\\Census Data\\Cleaned CSVs\\additional 20181205'
#set to the name of your output file
#results = 'ACSSF_2012_2016_Full.txt'

files = os.listdir('C:\\Census Data\\Cleaned CSVs\\additional 20181205')

#e20161ak0001000
#e = estimates
#2016 = year
#1 = 1 year estimate vs. 5 year
#ak = state
#0001 = sequence number
#000 = iterationID

#files2 = [k for k in files if '11' in k]
#files3 = [k for k in files2 if 'e2016' in k]
#files3 = [k for k in files2 if '0041' in k]


string = 'C:\\Census Data\\Cleaned CSVs\\additional 20181205\\'
files4 = [string + x for x in files]
files4
#files4
# Out:
# ['C:\\Census Data\\Cleaned CSVs\\additional 20181205\\csvfile41.csv',
#  'C:\\Census Data\\Cleaned CSVs\\additional 20181205\\csvfile76.csv']

# %%
logfile = pd.read_csv("C:\\Census Data\\LogRecReference.csv", engine='python')

logfile1a = logfile.loc[logfile['LOGRECNO'] == 1]
logfile1b = logfile.loc[logfile['Name'].str.contains('School') == 1]
logfile1c = logfile.loc[logfile['GEOID'].str.contains('61200') == 1]
logfile1d = logfile.loc[logfile['GEOID'].str.contains('86000') == 1]





logfile2 = pd.concat([logfile1a, logfile1b, logfile1c, logfile1d], sort=False, ignore_index=True)


#logfile2 = logfile



logfile = logfile2.drop(['source','Unnamed: 0','Name'], 1)
#logfile = logfile.loc[logfile['LOGRECNO'] == 1]


logfile
# Out:
#       STATE  LOGRECNO                   GEOID
# 0        AK         1               04000US02
# 1        AL         1               04000US01
# 2        AR         1               04000US05
# 3        AZ         1               04000US04
# 4        CA         1               04000US06
# 5        CO         1               04000US08
# 6        CT         1               04000US09
# 7        DC         1               04000US11
# 8        DE         1               04000US10
# 9        FL         1               04000US12
# 10       GA         1               04000US13
# 11       HI         1               04000US15
# 12       IA         1               04000US19
# 13       ID         1               04000US16
# 14       IL         1               04000US17
# 15       IN         1               04000US18
# 16       KS         1               04000US20
# 17       KY         1               04000US21
# 18       LA         1               04000US22
# ...

# %%
logfile
# Out:
#       STATE  LOGRECNO                   GEOID
# 0        AK         1               04000US02
# 1        AL         1               04000US01
# 2        AR         1               04000US05
# 3        AZ         1               04000US04
# 4        CA         1               04000US06
# 5        CO         1               04000US08
# 6        CT         1               04000US09
# 7        DC         1               04000US11
# 8        DE         1               04000US10
# 9        FL         1               04000US12
# 10       GA         1               04000US13
# 11       HI         1               04000US15
# 12       IA         1               04000US19
# 13       ID         1               04000US16
# 14       IL         1               04000US17
# 15       IN         1               04000US18
# 16       KS         1               04000US20
# 17       KY         1               04000US21
# 18       LA         1               04000US22
# ...

# %%
for f in files4:
  if f.endswith(ext):
    data = open(f)
    
        
    inputcsv = pd.read_csv(data,  engine='python')
    
    inputcsv = inputcsv.drop(['4','1','Unnamed: 0','GEOID','Name','YEAR'], 1)
    inputcsv.rename(index=str, columns= {'SEQ' : f})

    
    newcolumn = inputcsv['SEQ'].values
    seq_num = str(newcolumn[0])[0:2]
    new_Seq_columnname = "SEQ" + seq_num + "_"   

    columnnames = inputcsv.columns[~inputcsv.columns.str.contains('STATE|SEQ|LOGRECNO')]
    inputcsv.rename(columns = dict(zip(columnnames, new_Seq_columnname + columnnames)),inplace=True)
    
    logfile = pd.merge(logfile, inputcsv, on = ['LOGRECNO', 'STATE'], how = "left")    
    
    newcolumn = logfile['SEQ'].values

    seq_num = str(newcolumn[0])[0:2]
    seq_num = seq_num[0: seq_num.find(".")]
    new_Seq_columnname = "SEQ_"+ seq_num
        

    logfile.rename(columns = {'SEQ' : new_Seq_columnname}, inplace=True)
    
    data.close()

# %%
newfile = logfile

# %%
newfile
# Out:
#       STATE  LOGRECNO                   GEOID  SEQ_4  \
# 0        AK         1               04000US02   41.0
# 1        AL         1               04000US01   41.0
# 2        AR         1               04000US05   41.0
# 3        AZ         1               04000US04   41.0
# 4        CA         1               04000US06   41.0
# 5        CO         1               04000US08   41.0
# 6        CT         1               04000US09   41.0
# 7        DC         1               04000US11   41.0
# 8        DE         1               04000US10   41.0
# 9        FL         1               04000US12   41.0
# 10       GA         1               04000US13   41.0
# 11       HI         1               04000US15   41.0
# 12       IA         1               04000US19   41.0
# 13       ID         1               04000US16   41.0
# 14       IL         1               04000US17   41.0
# 15       IN         1               04000US18   41.0
# 16       KS         1               04000US20   41.0
# ...

# %%
## STOPPED HERE - NOT WORKING

#Education Attainment for 25 year olds + 



cols =[x for x in newfile.columns[newfile.columns.str.contains('STATE|LOGRECNO|GEOID|SEX BY SCHOOL ENROLLMENT BY TYPE OF SCHOOL BY AGE FOR THE POPULATION 3 YEARS AND OVER |16 TO 19 YEARS|SEX BY AGE BY EMPLOYMENT STATUS FOR THE POPULATION 16 YEARS AND OVER for Population 16 Years And Over')]]


newfile2 = newfile[cols]

newfile2.columns = newfile2.columns.str.strip().str.replace("%", '').str.replace('"', '')

cols2 = [x for x in newfile2.columns[newfile2.columns.str.contains('STATE|LOGRECNO|GEOID|SEX BY SCHOOL ENROLLMENT BY TYPE OF SCHOOL BY AGE FOR THE POPULATION 3 YEARS AND OVER |16 TO 19 YEARS|SEX BY AGE BY EMPLOYMENT STATUS FOR THE POPULATION 16 YEARS AND OVER for Population 16 Years And Over')]]
#cols2 = [x for x in fullfile2.columns[fullfile2.columns.str.contains('STATE|LOGRECNO|GEOID|ATTAINMENT')]]



additionalfiles = newfile2[cols2]

additionalfiles

#FilteredFileAdd4 = FilteredFileAdd4.drop(['NATIVITY IN THE UNITED STATES for Total Population In The United States Total',''], 1)

#keep education
#keep Enrollment
#keep proverty
#keep income
#keep ALLOCATION OF LANGUAGE SPOKEN AT HOME FOR THE POPULATION 5 YEARS
#POPULATION UNDER 18 YEARS BY AGE
# Out:
#       STATE  LOGRECNO                   GEOID  \
# 0        AK         1               04000US02
# 1        AL         1               04000US01
# 2        AR         1               04000US05
# 3        AZ         1               04000US04
# 4        CA         1               04000US06
# 5        CO         1               04000US08
# 6        CT         1               04000US09
# 7        DC         1               04000US11
# 8        DE         1               04000US10
# 9        FL         1               04000US12
# 10       GA         1               04000US13
# 11       HI         1               04000US15
# 12       IA         1               04000US19
# 13       ID         1               04000US16
# 14       IL         1               04000US17
# 15       IN         1               04000US18
# 16       KS         1               04000US20
# 17       KY         1               04000US21
# 18       LA         1               04000US22
# ...

# %%
FilteredFileOrg = pd.read_csv("\\\\Aopscifs004.amsa.com\\fs$\\DATA\\GROUP\\Insights and Outcomes\\IOG Projects\\National School District View\\Data\\201812 Cleaned Data\\FilteredFile.csv", engine='python')

# %%
geofile = pd.merge(FilteredFileOrg, additionalfiles, on = ['LOGRECNO', 'STATE'], how = "left")

# %%
geofile
#478  columns
# Out:
#        Unnamed: 0 STATE  LOGRECNO                 GEOID_x  \
# 0               0    AK         1               04000US02
# 1               1    AL         1               04000US01
# 2               2    AR         1               04000US05
# 3               3    AZ         1               04000US04
# 4               4    CA         1               04000US06
# 5               5    CO         1               04000US08
# 6               6    CT         1               04000US09
# 7               7    DC         1               04000US11
# 8               8    DE         1               04000US10
# 9               9    FL         1               04000US12
# 10             10    GA         1               04000US13
# 11             11    HI         1               04000US15
# 12             12    IA         1               04000US19
# 13             13    ID         1               04000US16
# 14             14    IL         1               04000US17
# ...

# %%
FilteredFileOrg #53739
# Out:
#        Unnamed: 0 STATE  LOGRECNO                   GEOID  \
# 0               0    AK         1               04000US02
# 1               1    AL         1               04000US01
# 2               2    AR         1               04000US05
# 3               3    AZ         1               04000US04
# 4               4    CA         1               04000US06
# 5               5    CO         1               04000US08
# 6               6    CT         1               04000US09
# 7               7    DC         1               04000US11
# 8               8    DE         1               04000US10
# 9               9    FL         1               04000US12
# 10             10    GA         1               04000US13
# 11             11    HI         1               04000US15
# 12             12    IA         1               04000US19
# 13             13    ID         1               04000US16
# 14             14    IL         1               04000US17
# ...

# %%
geofile.to_csv("\\\\Aopscifs004.amsa.com\\fs$\\DATA\\GROUP\\Insights and Outcomes\\IOG Projects\\National School District View\\Data\\201812 Cleaned Data\\FilteredFileAdd1.csv", sep=',', encoding='utf-8')
